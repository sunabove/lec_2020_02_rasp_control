# %%
! vcgencmd get_camera
# Out:
# supported=1 detected=1

# %%
! raspistill -o test.jpg

# %%
! ls -l test.jpg
# Out:
# -rw-r--r-- 1 pi pi 2483298 Mar 28 03:34 test.jpg

# %%
from IPython.display import Image
display( Image('test.jpg') )
