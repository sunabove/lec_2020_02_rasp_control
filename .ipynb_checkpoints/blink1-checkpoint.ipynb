# %%
# coding: utf-8
from gpiozero import LED
from time import sleep

led = LED(17)
try : 
    while True:
        led.on()
        sleep(1)
        led.off()
        sleep(1)
        print( "Running ...." )
    pass
except KeyboardInterrupt :
    led.off()
    print( "\nStopped.")
pass
# Out:
# ---------------------------------------------------------------------------
# GPIOPinInUse                              Traceback (most recent call last)
# <ipython-input-3-c111121d1780> in <module>()
#       3 from time import sleep
#       4
# ----> 5 led = LED(17)
#       6 try :
#       7     while True:
#
# /usr/lib/python3/dist-packages/gpiozero/devices.py in __call__(cls, *args, **kwargs)
#     122         else:
#     123             # Construct the instance as normal
# --> 124             self = super(GPIOMeta, cls).__call__(*args, **kwargs)
#     125         # At this point __new__ and __init__ have all been run. We now fix the
#     126         # set of attributes on the class by dir'ing the instance and creating a
#
# /usr/lib/python3/dist-packages/gpiozero/output_devices.py in __init__(self, pin, active_high, initial_value, pin_factory)
#     209         self._controller = None
#     210         super(DigitalOutputDevice, self).__init__(
# ...
